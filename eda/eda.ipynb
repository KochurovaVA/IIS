# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource
from bokeh.layouts import row, column
import numpy as np
from pathlib import Path
import os

# %% [markdown]
# ## Загрузка и знакомство с данными

# %%
Dat = pd.read_csv("C:/home/mainuser/my_proj/data/dataset.csv", sep=';')

# %%
Dat.head(10)
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
# 7   39     technician  married  secondary      no      147     yes   no
# 8   41   entrepreneur  married   tertiary      no      221     yes   no
# 9   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no
# 5  cellular   23   feb       141         2    176         3  failure  no
# 6  cellular   14   may       341         1    330         2    other  no
# 7  cellular    6   may       151         2     -1         0  unknown  no
# 8   unknown   14   may        57         2     -1         0  unknown  no
# 9  cellular   17   apr       313         1    147         2  failure  no

# %%
Dat.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
Dat.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %% [markdown]
# ## Очистка данных

# %%
Dat = Dat.drop(["pdays","previous", "poutcome"], axis=1)

# %%
NumerColumns = Dat.select_dtypes(include=['number']).columns 
CategorColumns = Dat.select_dtypes(include=['object']).columns

# %%
NumerColumns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign'], dtype='object')

# %%
CategorColumns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'y'],
#       dtype='object')

# %%
for f in CategorColumns:
    Dat[f] = Dat[f].astype('category')

# %%
Dat["default"].cat.codes
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4516    0
# 4517    1
# 4518    0
# 4519    0
# 4520    0
# Length: 4521, dtype: int8

# %%
Dat['age'] = Dat['age'].astype('uint8')
Dat['balance'] = Dat['balance'].astype('float32')
Dat['day'] = Dat['day'].astype('uint32')
Dat['duration'] = Dat['duration'].astype('uint32')
Dat['campaign'] = Dat['campaign'].astype('uint32')

# %%
Dat.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   uint8
#  1   job        4521 non-null   category
#  2   marital    4521 non-null   category
#  3   education  4521 non-null   category
#  4   default    4521 non-null   category
#  5   balance    4521 non-null   float32
#  6   housing    4521 non-null   category
#  7   loan       4521 non-null   category
#  8   contact    4521 non-null   category
#  9   day        4521 non-null   uint32
#  10  month      4521 non-null   category
#  11  duration   4521 non-null   uint32
#  12  campaign   4521 non-null   uint32
#  13  y          4521 non-null   category
# dtypes: category(9), float32(1), uint32(3), uint8(1)
# memory usage: 116.6 KB

# %%
for cat in CategorColumns:
    print(f'{cat} - numer of unique = {Dat[cat].nunique()}')
# Out:
# job - numer of unique = 12
# marital - numer of unique = 3
# education - numer of unique = 4
# default - numer of unique = 2
# housing - numer of unique = 2
# loan - numer of unique = 2
# contact - numer of unique = 3
# month - numer of unique = 12
# y - numer of unique = 2

# %%
for col in CategorColumns:
    print(f'Unique categories in {col}: {Dat[col].value_counts()}')
# Out:
# Unique categories in job: job
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: count, dtype: int64
# Unique categories in marital: marital
# married     2797
# single      1196
# divorced     528
# Name: count, dtype: int64
# Unique categories in education: education
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: count, dtype: int64
# Unique categories in default: default
# no     4445
# yes      76
# Name: count, dtype: int64
# Unique categories in housing: housing
# yes    2559
# no     1962
# Name: count, dtype: int64
# Unique categories in loan: loan
# no     3830
# yes     691
# Name: count, dtype: int64
# Unique categories in contact: contact
# cellular     2896
# unknown      1324
# telephone     301
# Name: count, dtype: int64
# Unique categories in month: month
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: count, dtype: int64
# Unique categories in y: y
# no     4000
# yes     521
# Name: count, dtype: int64

# %%
Dat.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# y            0
# dtype: int64

# %% [markdown]
# ## Анализ признаков для модели

# %%
import plotly.express as px 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from bokeh.layouts import row, column
import numpy as np
from pathlib import Path
import os
from bokeh.plotting import figure, show, output_file
import pickle
from bokeh.models import ColumnDataSource,  HoverTool, Legend
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e2aed0ee-8dcd-4bd4-a0e9-96f2bccc5a01">Loading BokehJS ...</span>
#     </div>

# %%
Dat_CorrelaionMatrix = Dat.copy() 
Dat_CorrelaionMatrix['y'] = Dat_CorrelaionMatrix['y'].apply(lambda x: 1 if x == 'yes' else 0)

CorrelaionMatrix = Dat_CorrelaionMatrix[NumerColumns].corr()
plt.figure(figsize=(10, 5))
sns.heatmap(CorrelaionMatrix, annot=True, cmap='magma')
plt.title('Матрица корреляции', fontsize=11)
plt.show()

# %% [markdown]
# На выведенной матрице наблюдаем слабую связь между признаками

# %%
import plotly.express as px 
fig=px.box(Dat,x='job',y='balance',color='job',title='Соотношение баланса и трудоустройства')
fig.update_layout(
     title={
         'y':0.9,
         'x':0.5,
         'xanchor':'center',
         
         'yanchor':'top'
     }
)
fig.show()

# %% [markdown]
# Данный график иллюстрирует зависимость значения баланса от профессии и трудоустройства. В среднем у управленцев и работников технических профессий баланс больше, чем у студентов и безработных

# %%
GroupDat = Dat.groupby(['marital', 'y'], as_index=False)['age'].count()
GroupDat.rename(columns={'age': 'count'}, inplace=True)

plt.figure(figsize=(21, 15))
sns.barplot(x='marital', y='count', hue='y', data=GroupDat, palette="cividis")

plt.xlabel('статус', fontsize=25)
plt.ylabel('количество', fontsize=25)
plt.title('Зависимость отказов от семейного положения', fontsize=20)

plt.grid(True, which='both', linestyle='-', linewidth=1)

legend = plt.legend(fontsize=15, title_fontsize=19)
legend.get_title().set_fontsize('21')

plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5276\975009366.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   GroupDat = Dat.groupby(['marital', 'y'], as_index=False)['age'].count()

# %% [markdown]
# Как видно на графике, женатым/замужним клиентам(кам) отказывает в выдаче кредита чаще, чем разведённым и холостым/незамужним

# %%
fig, axs = plt.subplots(1,5)
fig.tight_layout(pad=3)
fig.set_size_inches(15, 7, forward=True)
for i,f in enumerate(NumerColumns):
    sns.boxplot(data = Dat[f], ax=axs[i])

# %%
GroupDat = Dat.groupby(['y','housing', 'loan'], as_index=False)['age'].count()
GroupDat.rename(columns={'age':'count'}, inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5276\1459438153.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   GroupDat = Dat.groupby(['y','housing', 'loan'], as_index=False)['age'].count()

# %%
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource,  HoverTool, Legend
from bokeh.io import output_notebook 
from bokeh.io.export import get_screenshot_as_png

output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c94b62a4-4a36-4fdf-b6bc-e215cb4459c1">Loading BokehJS ...</span>
#     </div>

# %%
source = ColumnDataSource(data=Dat.sample(frac=0.1))
t = figure(width=1000)
t.scatter(source=source, x='age', y='balance')
hvr = HoverTool(tooltips=[('loan ', '@loan'),
                              ('marital', '@marital'),
                              ('balance', '@balance')])

t.add_tools(hvr)
show(t)
# Out:
#   <div id="fc19f904-72cd-48c5-90a8-aa022a4cebdd" data-root-id="p1004" style="display: contents;"></div>

# %% [markdown]
# В среднем около 35 и 55 лет баланс выше, чем в другие периоды жизни.

# %%
plt.figure(figsize=(17, 11))
sns.barplot(x='housing', y='count', hue='y', data=GroupDat, palette="cividis")

plt.xlabel('иппотека', fontsize=9)
plt.ylabel('количество', fontsize=11)
plt.title('Связь ипотеки и согласия', fontsize=16)

plt.grid(True, which='both', linestyle='-', linewidth=1)

legend = plt.legend(title='y', fontsize=15, title_fontsize=17)
legend.get_title().set_fontsize('19')

plt.show()

# %% [markdown]
# Как видно на графике, в ипотеке отказывают чаще, чем в кредитах на другие нужды

# %% [markdown]
# ## Сохранение итоговой выборки

# %%
Dat.to_pickle('../data/clean_dataset.pkl')
